# %%
# Import key libraries and paths
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

# %%
path = 'C:/Users/Anne Joo Marthinsen/Documents/GitHub/adventofcode23'
with open('day1-calibration.txt') as f:
    lines = f.readlines()

# %%
numbers_text = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
numbers_int = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def find_first_number_text(line):
    for i in range(len(line)):
        front_sub_line = line[0:i]
        for j in range(9):
            if numbers_text[j] in front_sub_line:
                return numbers_int[j], i-len(numbers_text[j])
    return None, None

def find_last_number_text(line):
    for i in range(1,len(line)):
        back_sub_line = line[-i:]
        for j in range(9):
            if numbers_text[j] in back_sub_line:
                return numbers_int[j], len(line)-i
    return None, None

def find_first_number_int(line):
    for i in range(len(line)):
        if line[i].isnumeric():
            return int(line[i]), i
    return None, None

def find_last_number_int(line):
    for i in range(1, len(line) + 1):
        if line[-i].isnumeric():
            return int(line[-i]), len(line)-i
    return None, None

# %%
print(lines[0])
first_num_t, i = find_first_number_text(lines[0])
first_num_i, j = find_first_number_int(lines[0])
print(f'first numbers and positions {first_num_t, i} and {first_num_i, j}')

last_num_t, k = find_last_number_text(lines[0])
last_num_i, l = find_last_number_int(lines[0])
print(f'last numbers and positions {last_num_t, k} and {last_num_i, l}')

if first_num_t == None:
    first_num = first_num_i
elif fist_num_i == None:
    fist_num = fist_num_t
elif i < j:
    first_num = first_num_t
else:
    first_num = first_num_i

if last_num_t == None:
    last_num = last_num_i
elif last_num_i == None:
    last_num_i = last_num_t
elif k > l:
    last_num = last_num_t
else:
    last_num = last_num_i

print(f'Final first and last numbers {first_num, last_num}')
# Out:
# shrzvdcghblt21
#
# first numbers and positions (None, None) and (2, 12)
# last numbers and positions (None, None) and (1, 13)
# Final first and last numbers (2, 1)

# %%
tot = 0
for line in lines:
    print('-----------------')
    print(line)
    first_num_t, i = find_first_number_text(line)
    first_num_i, j = find_first_number_int(line)
    print(f'first numbers and positions {first_num_t, i} and {first_num_i, j}')
    
    last_num_t, k = find_last_number_text(line)
    last_num_i, l = find_last_number_int(line)
    print(f'last numbers and positions {last_num_t, k} and {last_num_i, l}')

    if first_num_t == None:
        first_num = first_num_i
    elif first_num_i == None:
        first_num = fist_num_t
    elif i < j:
        first_num = first_num_t
    else:
        first_num = first_num_i

    if last_num_t == None:
        last_num = last_num_i
    elif last_num_i == None:
        last_num_i = last_num_t
    elif k > l:
        last_num = last_num_t
    else:
        last_num = last_num_i

    print(f'Final first and last numbers {first_num, last_num}')
    sum = int(str(first_num)+str(last_num))
    tot+=sum

print(tot)
# Out:
# -----------------
# shrzvdcghblt21
#
# first numbers and positions (None, None) and (2, 12)
# last numbers and positions (None, None) and (1, 13)
# Final first and last numbers (2, 1)
# -----------------
# sixdddkcqjdnzzrgfourxjtwosevenhg9
#
# first numbers and positions (6, 0) and (9, 32)
# last numbers and positions (7, 25) and (9, 32)
# Final first and last numbers (6, 9)
# -----------------
# threevt1onegxgvc9flk
#
# first numbers and positions (3, 0) and (1, 7)
# last numbers and positions (1, 8) and (9, 16)
# Final first and last numbers (3, 9)
# -----------------
# 7dmqzksnlcpbsqkzqlfour1four
#
# first numbers and positions (4, 18) and (7, 0)
# last numbers and positions (4, 23) and (1, 22)
# Final first and last numbers (7, 4)
# -----------------
# 4seven9gdlnhqxfseven94five
#
# first numbers and positions (7, 1) and (4, 0)
# last numbers and positions (5, 22) and (4, 21)
# Final first and last numbers (4, 5)
# -----------------
# nldeightwoshgnsjnzmbkbxcxltsqtstrgdmvqvxbfour6six
#
# first numbers and positions (8, 3) and (6, 45)
# last numbers and positions (6, 46) and (6, 45)
# Final first and last numbers (8, 6)
# -----------------
# 87mmlvfr4
#
# first numbers and positions (None, None) and (8, 0)
# last numbers and positions (None, None) and (4, 8)
# Final first and last numbers (8, 4)
# -----------------
# six1vvrlxx8two
#
# first numbers and positions (6, 0) and (1, 3)
# last numbers and positions (2, 11) and (8, 10)
# Final first and last numbers (6, 2)
# -----------------
# znmfvdlhvjtwo9three4tzjqcfcgnsevenccvnsjczlpm
#
# first numbers and positions (2, 10) and (9, 13)
# last numbers and positions (7, 29) and (4, 19)
# Final first and last numbers (2, 7)
# -----------------
# 5sixninesixnh
#
# first numbers and positions (6, 1) and (5, 0)
# last numbers and positions (6, 8) and (5, 0)
# Final first and last numbers (5, 6)
# -----------------
# three1tbtwo
#
# first numbers and positions (3, 0) and (1, 5)
# last numbers and positions (2, 8) and (1, 5)
# Final first and last numbers (3, 2)
# -----------------
# five9seventwobqsjqzxkptkhsix1
#
# first numbers and positions (5, 0) and (9, 4)
# last numbers and positions (6, 25) and (1, 28)
# Final first and last numbers (5, 1)
# -----------------
# 74fivemn
#
# first numbers and positions (5, 2) and (7, 0)
# last numbers and positions (5, 2) and (4, 1)
# Final first and last numbers (7, 5)
# -----------------
# sevenfivetsglnine8three
#
# first numbers and positions (7, 0) and (8, 17)
# last numbers and positions (3, 18) and (8, 17)
# Final first and last numbers (7, 3)
# -----------------
# spnvnfkbv4eightlmdkxmsfour574eight
#
# first numbers and positions (8, 10) and (4, 9)
# last numbers and positions (8, 29) and (4, 28)
# Final first and last numbers (4, 8)
# -----------------
# one4four2fivedcpqjmgc8
#
# first numbers and positions (1, 0) and (4, 3)
# last numbers and positions (5, 9) and (8, 21)
# Final first and last numbers (1, 8)
# -----------------
# two6sevensix33
#
# first numbers and positions (2, 0) and (6, 3)
# last numbers and positions (6, 9) and (3, 13)
# Final first and last numbers (2, 3)
# -----------------
# krc34five
#
# first numbers and positions (5, 5) and (3, 3)
# last numbers and positions (5, 5) and (4, 4)
# Final first and last numbers (3, 5)
# -----------------
# doneight64qgc251four7
#
# first numbers and positions (1, 1) and (6, 8)
# last numbers and positions (4, 16) and (7, 20)
# Final first and last numbers (1, 7)
# -----------------
# vpjthc6
#
# first numbers and positions (None, None) and (6, 6)
# last numbers and positions (None, None) and (6, 6)
# Final first and last numbers (6, 6)
# -----------------
# threethxbtffhbfourfive3
#
# first numbers and positions (3, 0) and (3, 22)
# last numbers and positions (5, 18) and (3, 22)
# Final first and last numbers (3, 3)
# -----------------
# onetwo5
#
# first numbers and positions (1, 0) and (5, 6)
# last numbers and positions (2, 3) and (5, 6)
# Final first and last numbers (1, 5)
# -----------------
# 1sevenngjqsfrptq8stgzxgjfp
#
# first numbers and positions (7, 1) and (1, 0)
# last numbers and positions (7, 1) and (8, 16)
# Final first and last numbers (1, 8)
# -----------------
# 1576sevenninefhfqd4
#
# first numbers and positions (7, 4) and (1, 0)
# last numbers and positions (9, 9) and (4, 18)
# Final first and last numbers (1, 4)
# -----------------
# nine4nine9ninefive
#
# first numbers and positions (9, 0) and (4, 4)
# last numbers and positions (5, 14) and (9, 9)
# Final first and last numbers (9, 5)
# -----------------
# zp8sfveight9twotgbvscb
#
# first numbers and positions (8, 6) and (8, 2)
# last numbers and positions (2, 12) and (9, 11)
# Final first and last numbers (8, 2)
# -----------------
# eight27nrzmfsix7nine7two
#
# first numbers and positions (8, 0) and (2, 5)
# last numbers and positions (2, 21) and (7, 20)
# Final first and last numbers (8, 2)
# -----------------
# gsfivefivepmq9nineftndvlcph
#
# first numbers and positions (5, 2) and (9, 13)
# last numbers and positions (9, 14) and (9, 13)
# Final first and last numbers (5, 9)
# -----------------
# znggdvvkjthreethree79eight4
#
# first numbers and positions (3, 9) and (7, 19)
# last numbers and positions (8, 21) and (4, 26)
# Final first and last numbers (3, 4)
# -----------------
# 7twofivethree7ninevtspmbfxnr
#
# first numbers and positions (2, 1) and (7, 0)
# last numbers and positions (9, 14) and (7, 13)
# Final first and last numbers (7, 9)
# -----------------
# four9twoxthdxdc7two1
#
# first numbers and positions (4, 0) and (9, 4)
# last numbers and positions (2, 16) and (1, 19)
# Final first and last numbers (4, 1)
# -----------------
# 8ddcmt87xhkqjbgtmkpjlkhd7sevenfour
#
# first numbers and positions (7, 25) and (8, 0)
# last numbers and positions (4, 30) and (7, 24)
# Final first and last numbers (8, 4)
# -----------------
# 4four6
#
# first numbers and positions (4, 1) and (4, 0)
# last numbers and positions (4, 1) and (6, 5)
# Final first and last numbers (4, 6)
# -----------------
# seven5tmzksnsv9six
#
# first numbers and positions (7, 0) and (5, 5)
# last numbers and positions (6, 15) and (9, 14)
# Final first and last numbers (7, 6)
# -----------------
# 6fivesixlxfrqbkfive
#
# first numbers and positions (5, 1) and (6, 0)
# last numbers and positions (5, 15) and (6, 0)
# Final first and last numbers (6, 5)
# -----------------
# seven9one8jxqkhbfppt
#
# first numbers and positions (7, 0) and (9, 5)
# last numbers and positions (1, 6) and (8, 9)
# Final first and last numbers (7, 8)
# -----------------
# hxsbgn6four7
#
# first numbers and positions (4, 7) and (6, 6)
# last numbers and positions (4, 7) and (7, 11)
# Final first and last numbers (6, 7)
# -----------------
# 7pglchqndpnknhvcnkthreefour2
#
# first numbers and positions (3, 18) and (7, 0)
# last numbers and positions (4, 23) and (2, 27)
# Final first and last numbers (7, 2)
# -----------------
# bkkfjq6dklbppfvgsshgrbmtwo97
#
# first numbers and positions (2, 23) and (6, 6)
# last numbers and positions (2, 23) and (7, 27)
# Final first and last numbers (6, 7)
# -----------------
# 66eightsix3nine652
#
# first numbers and positions (8, 2) and (6, 0)
# last numbers and positions (9, 11) and (2, 17)
# Final first and last numbers (6, 2)
# -----------------
# six6zjjfffhrflrvkjgdrstcqpqt1eight
#
# first numbers and positions (6, 0) and (6, 3)
# last numbers and positions (8, 29) and (1, 28)
# Final first and last numbers (6, 8)
# -----------------
# four252bqdxzzfttkq85tqnl
#
# first numbers and positions (4, 0) and (2, 4)
# last numbers and positions (None, None) and (5, 19)
# Final first and last numbers (4, 5)
# -----------------
# pbgjmdfxjvzdxjjdtwo5sixtwofivesxdcxtn
#
# first numbers and positions (2, 16) and (5, 19)
# last numbers and positions (5, 26) and (5, 19)
# Final first and last numbers (2, 5)
# -----------------
# jonesix2five4snxcbgmx
#
# first numbers and positions (1, 1) and (2, 7)
# last numbers and positions (5, 8) and (4, 12)
# Final first and last numbers (1, 4)
# -----------------
# 62rceightsix
#
# first numbers and positions (8, 4) and (6, 0)
# last numbers and positions (6, 9) and (2, 1)
# Final first and last numbers (6, 6)
# -----------------
# fivenine5
#
# first numbers and positions (5, 0) and (5, 8)
# last numbers and positions (9, 4) and (5, 8)
# Final first and last numbers (5, 5)
# -----------------
# nzcxfqhvninefive3nz
#
# first numbers and positions (9, 8) and (3, 16)
# last numbers and positions (5, 12) and (3, 16)
# Final first and last numbers (9, 3)
# -----------------
# 4474rcl
#
# first numbers and positions (None, None) and (4, 0)
# last numbers and positions (None, None) and (4, 3)
# Final first and last numbers (4, 4)
# -----------------
# 1bjlvthree1tjthreethree
#
# first numbers and positions (3, 5) and (1, 0)
# last numbers and positions (3, 18) and (1, 10)
# Final first and last numbers (1, 3)
# -----------------
# bgx2six8vlbdmgsrkone9bdgzsfljlk
#
# first numbers and positions (6, 4) and (2, 3)
# last numbers and positions (1, 17) and (9, 20)
# Final first and last numbers (2, 9)
# -----------------
# seven52
#
# first numbers and positions (7, 0) and (5, 5)
# last numbers and positions (None, None) and (2, 6)
# Final first and last numbers (7, 2)
# -----------------
# fivesixtwo1two
#
# first numbers and positions (5, 0) and (1, 10)
# last numbers and positions (2, 11) and (1, 10)
# Final first and last numbers (5, 2)
# -----------------
# njznm98
#
# first numbers and positions (None, None) and (9, 5)
# last numbers and positions (None, None) and (8, 6)
# Final first and last numbers (9, 8)
# -----------------
# 3xhrsfshnine7five
#
# first numbers and positions (9, 8) and (3, 0)
# last numbers and positions (5, 13) and (7, 12)
# Final first and last numbers (3, 5)
# -----------------
# four9eightzcmsevennzfrxtsixone
#
# first numbers and positions (4, 0) and (9, 4)
# last numbers and positions (1, 27) and (9, 4)
# Final first and last numbers (4, 1)
# -----------------
# jjsxs4mgqnstgpreight1
#
# first numbers and positions (8, 15) and (4, 5)
# last numbers and positions (8, 15) and (1, 20)
# Final first and last numbers (4, 1)
# -----------------
# bhv9kr8three
#
# first numbers and positions (3, 7) and (9, 3)
# last numbers and positions (3, 7) and (8, 6)
# Final first and last numbers (9, 3)
# -----------------
# sklnine1six4
#
# first numbers and positions (9, 3) and (1, 7)
# last numbers and positions (6, 8) and (4, 11)
# Final first and last numbers (9, 4)
# -----------------
# five52734eighttghkkszrdllrr
#
# first numbers and positions (5, 0) and (5, 4)
# last numbers and positions (8, 9) and (4, 8)
# Final first and last numbers (5, 8)
# -----------------
# 93one
#
# first numbers and positions (1, 2) and (9, 0)
# last numbers and positions (1, 2) and (3, 1)
# Final first and last numbers (9, 1)
# -----------------
# qrlmcmfgsx55onetwo
#
# first numbers and positions (1, 12) and (5, 10)
# last numbers and positions (2, 15) and (5, 11)
# Final first and last numbers (5, 2)
# -----------------
# 86dnnrmms6gxskhcghct97glkrlzrdrscfcld
#
# first numbers and positions (None, None) and (8, 0)
# last numbers and positions (None, None) and (7, 21)
# Final first and last numbers (8, 7)
# -----------------
# xxb283cftvdg
#
# first numbers and positions (None, None) and (2, 3)
# last numbers and positions (None, None) and (3, 5)
# Final first and last numbers (2, 3)
# -----------------
# hxtwoneqpmbfgkhnr6three86eight7five
#
# first numbers and positions (2, 2) and (6, 17)
# last numbers and positions (5, 31) and (7, 30)
# Final first and last numbers (2, 5)
# -----------------
# zjfczdbpgxtkffkl5
#
# first numbers and positions (None, None) and (5, 16)
# last numbers and positions (None, None) and (5, 16)
# Final first and last numbers (5, 5)
# -----------------
# fivexnqvfiveoneszqkzdfclxkrj8
#
# first numbers and positions (5, 0) and (8, 28)
# last numbers and positions (1, 12) and (8, 28)
# Final first and last numbers (5, 8)
# -----------------
# 8onerj7mhl
#
# first numbers and positions (1, 1) and (8, 0)
# last numbers and positions (1, 1) and (7, 6)
# Final first and last numbers (8, 7)
# -----------------
# 6fivefive8eightsevenqc8
#
# first numbers and positions (5, 1) and (6, 0)
# last numbers and positions (7, 15) and (8, 22)
# Final first and last numbers (6, 8)
# -----------------
# eight89nineonelmfst193
#
# first numbers and positions (8, 0) and (8, 5)
# last numbers and positions (1, 11) and (3, 21)
# Final first and last numbers (8, 3)
# -----------------
# ninetwothree5six5gd8
#
# first numbers and positions (9, 0) and (5, 12)
# last numbers and positions (6, 13) and (8, 19)
# Final first and last numbers (9, 8)
# -----------------
# eight6dvvd
#
# first numbers and positions (8, 0) and (6, 5)
# last numbers and positions (None, None) and (6, 5)
# Final first and last numbers (8, 6)
# -----------------
# sevenztbdzndhv5threefour
#
# first numbers and positions (7, 0) and (5, 14)
# last numbers and positions (4, 20) and (5, 14)
# Final first and last numbers (7, 4)
# -----------------
# two8onebppzkln6
#
# first numbers and positions (2, 0) and (8, 3)
# last numbers and positions (1, 4) and (6, 14)
# Final first and last numbers (2, 6)
# -----------------
# twothree54six
#
# first numbers and positions (2, 0) and (5, 8)
# last numbers and positions (6, 10) and (4, 9)
# Final first and last numbers (2, 6)
# -----------------
# seven8ninetwonndtgkj1
#
# first numbers and positions (7, 0) and (8, 5)
# last numbers and positions (2, 10) and (1, 20)
# Final first and last numbers (7, 1)
# -----------------
# cpjckcfnqrrgdzfbrtbdfive8vkl
#
# first numbers and positions (5, 20) and (8, 24)
# last numbers and positions (5, 20) and (8, 24)
# Final first and last numbers (5, 8)
# -----------------
# 6six5jzxqqtrpflpdqbkgktsvpjgrhggsmvltwomq
#
# first numbers and positions (6, 1) and (6, 0)
# last numbers and positions (2, 36) and (5, 4)
# Final first and last numbers (6, 2)
# -----------------
# sixhbft5lnqfseventhreefour
#
# first numbers and positions (6, 0) and (5, 7)
# last numbers and positions (4, 22) and (5, 7)
# Final first and last numbers (6, 4)
# -----------------
# 23pqkgleightxvscbnxnp55rb
#
# first numbers and positions (8, 7) and (2, 0)
# last numbers and positions (8, 7) and (5, 22)
# Final first and last numbers (2, 5)
# -----------------
# 6fivesfhqmzm7qkdvjss8
#
# first numbers and positions (5, 1) and (6, 0)
# last numbers and positions (5, 1) and (8, 20)
# Final first and last numbers (6, 8)
# -----------------
# twofivefiveeightdcl4
#
# first numbers and positions (2, 0) and (4, 19)
# last numbers and positions (8, 11) and (4, 19)
# Final first and last numbers (2, 4)
# -----------------
# 9fourfourdqfqhpbbkgtchk2nrvmrghnkdc
#
# first numbers and positions (4, 1) and (9, 0)
# last numbers and positions (4, 5) and (2, 23)
# Final first and last numbers (9, 2)
# -----------------
# sixlzbpttdhlssixdhmvrrgxj6
#
# first numbers and positions (6, 0) and (6, 25)
# last numbers and positions (6, 13) and (6, 25)
# Final first and last numbers (6, 6)
# -----------------
# glphjgxqvbjcqjpdsixlsgd3
#
# first numbers and positions (6, 16) and (3, 23)
# last numbers and positions (6, 16) and (3, 23)
# Final first and last numbers (6, 3)
# -----------------
# qcghmvgbmj9fourfivepztxbjpnzpbxzckgnhd4
#
# first numbers and positions (4, 11) and (9, 10)
# last numbers and positions (5, 15) and (4, 38)
# Final first and last numbers (9, 4)
# -----------------
# kjvoneighteightfivepsbkgdgpndxx7six8
#
# first numbers and positions (1, 3) and (7, 31)
# last numbers and positions (6, 32) and (8, 35)
# Final first and last numbers (1, 8)
# -----------------
# five95oneeighttpdk64xxndq
#
# first numbers and positions (5, 0) and (9, 4)
# last numbers and positions (8, 9) and (4, 19)
# Final first and last numbers (5, 4)
# -----------------
# 1vqxhglhnhrpbnlvq
#
# first numbers and positions (None, None) and (1, 0)
# last numbers and positions (None, None) and (1, 0)
# Final first and last numbers (1, 1)
# -----------------
# sixtwo34sevensevenrnflkfxmlthree
#
# first numbers and positions (6, 0) and (3, 6)
# last numbers and positions (3, 27) and (4, 7)
# Final first and last numbers (6, 3)
# -----------------
# pbscshhhpeighteight668fourphkdcrjrf
#
# first numbers and positions (8, 9) and (6, 19)
# last numbers and positions (4, 22) and (8, 21)
# Final first and last numbers (8, 4)
# -----------------
# threex1jpdsmc
#
# first numbers and positions (3, 0) and (1, 6)
# last numbers and positions (None, None) and (1, 6)
# Final first and last numbers (3, 1)
# -----------------
# 4pnhtjzlfdcgffour3
#
# first numbers and positions (4, 13) and (4, 0)
# last numbers and positions (4, 13) and (3, 17)
# Final first and last numbers (4, 3)
# -----------------
# 338
#
# first numbers and positions (None, None) and (3, 0)
# last numbers and positions (None, None) and (8, 2)
# Final first and last numbers (3, 8)
# -----------------
# 62six7nn
#
# first numbers and positions (6, 2) and (6, 0)
# last numbers and positions (6, 2) and (7, 5)
# Final first and last numbers (6, 7)
# -----------------
# 1fgq3onethree
#
# first numbers and positions (1, 5) and (1, 0)
# last numbers and positions (3, 8) and (3, 4)
# Final first and last numbers (1, 3)
# -----------------
# 7eightzvxmvxbq965nine1hr
#
# first numbers and positions (8, 1) and (7, 0)
# last numbers and positions (9, 17) and (1, 21)
# Final first and last numbers (7, 1)
# -----------------
# gsdqtgkhlhdff7fourtwo4threesixthree
#
# first numbers and positions (4, 14) and (7, 13)
# last numbers and positions (3, 30) and (4, 21)
# Final first and last numbers (7, 3)
# -----------------
# 918hjpgbz6kbdxeight9one
#
# first numbers and positions (8, 14) and (9, 0)
# last numbers and positions (1, 20) and (9, 19)
# Final first and last numbers (9, 1)
# -----------------
# 7dxhsk9ninejjbninefour
#
# first numbers and positions (9, 7) and (7, 0)
# last numbers and positions (4, 18) and (9, 6)
# Final first and last numbers (7, 4)
# -----------------
# one2mblcjnine
#
# first numbers and positions (1, 0) and (2, 3)
# last numbers and positions (9, 9) and (2, 3)
# Final first and last numbers (1, 9)
# -----------------
# 9twoc
#
# first numbers and positions (2, 1) and (9, 0)
# last numbers and positions (2, 1) and (9, 0)
# Final first and last numbers (9, 2)
# -----------------
# fxrkzvpkb3tdvlxxchbfsixbmmmctknxh1
#
# first numbers and positions (6, 20) and (3, 9)
# last numbers and positions (6, 20) and (1, 33)
# Final first and last numbers (3, 1)
# -----------------
# pbzdkmkxczkgh5xsixtwo6kfgqsgx
#
# first numbers and positions (6, 15) and (5, 13)
# last numbers and positions (2, 18) and (6, 21)
# Final first and last numbers (5, 6)
# -----------------
# 6eighttwodsfppgxrzx9threeseven
#
# first numbers and positions (8, 1) and (6, 0)
# last numbers and positions (7, 25) and (9, 19)
# Final first and last numbers (6, 7)
# -----------------
# zzkbhltv7ngthreetwofivegdzrmllnxp
#
# first numbers and positions (3, 11) and (7, 8)
# last numbers and positions (5, 19) and (7, 8)
# Final first and last numbers (7, 5)
# -----------------
# sgfour67three2seven3
#
# first numbers and positions (4, 2) and (6, 6)
# last numbers and positions (7, 14) and (3, 19)
# Final first and last numbers (4, 3)
# -----------------
# sqglnvlrn4sixmdnineeightthree
#
# first numbers and positions (6, 10) and (4, 9)
# last numbers and positions (3, 24) and (4, 9)
# Final first and last numbers (4, 3)
# -----------------
# 1kbkmkdnc35eightxbbknllscr
#
# first numbers and positions (8, 11) and (1, 0)
# last numbers and positions (8, 11) and (5, 10)
# Final first and last numbers (1, 8)
# -----------------
# 2bzrg
#
# first numbers and positions (None, None) and (2, 0)
# last numbers and positions (None, None) and (2, 0)
# Final first and last numbers (2, 2)
# -----------------
# 3onenine
#
# first numbers and positions (1, 1) and (3, 0)
# last numbers and positions (9, 4) and (3, 0)
# Final first and last numbers (3, 9)
# -----------------
# threevkzrmdbnbsxrmzjtdhbeight12rncbzmq
#
# first numbers and positions (3, 0) and (1, 29)
# last numbers and positions (8, 24) and (2, 30)
# Final first and last numbers (3, 2)
# -----------------
# sxcrgkvbrtwo17six527five
#
# first numbers and positions (2, 9) and (1, 12)
# last numbers and positions (5, 20) and (7, 19)
# Final first and last numbers (2, 5)
# -----------------
# 9rbsbcjp239jvlfpn5jrr
#
# first numbers and positions (None, None) and (9, 0)
# last numbers and positions (None, None) and (5, 17)
# Final first and last numbers (9, 5)
# -----------------
# nine8vjcbjcxxprdcf4
#
# first numbers and positions (9, 0) and (8, 4)
# last numbers and positions (None, None) and (4, 18)
# Final first and last numbers (9, 4)
# -----------------
# nineeightsevenchjczgdvjvtqlkjsqvrzxxvlqlp65
#
# first numbers and positions (9, 0) and (6, 41)
# last numbers and positions (7, 9) and (5, 42)
# Final first and last numbers (9, 5)
# -----------------
# hdgqninefive9sevensix3gzb
#
# first numbers and positions (9, 4) and (9, 12)
# last numbers and positions (6, 18) and (3, 21)
# Final first and last numbers (9, 3)
# -----------------
# 6fjv5
#
# first numbers and positions (None, None) and (6, 0)
# last numbers and positions (None, None) and (5, 4)
# Final first and last numbers (6, 5)
# -----------------
# pmgdvcdp1fivetxkmjzone
#
# first numbers and positions (5, 9) and (1, 8)
# last numbers and positions (1, 19) and (1, 8)
# Final first and last numbers (1, 1)
# -----------------
# eightsevenklxgcj8sixccqlnxzmbeight
#
# first numbers and positions (8, 0) and (8, 16)
# last numbers and positions (8, 29) and (8, 16)
# Final first and last numbers (8, 8)
# -----------------
# bkcdmscssixsixtwozbdzcpgpbsvf38
#
# first numbers and positions (6, 8) and (3, 29)
# last numbers and positions (2, 14) and (8, 30)
# Final first and last numbers (6, 8)
# -----------------
# ninefourrcmrfvszsqhpxcs89onecnzjvhrphs
#
# first numbers and positions (9, 0) and (8, 23)
# last numbers and positions (1, 25) and (9, 24)
# Final first and last numbers (9, 1)
# -----------------
# 54plhhmnmkvonethree2ktzncds
#
# first numbers and positions (1, 11) and (5, 0)
# last numbers and positions (3, 14) and (2, 19)
# Final first and last numbers (5, 2)
# -----------------
# pkglbgdplgvlstpgpnsmlsixcpmfxfbfbtpsdxninenine4
#
# first numbers and positions (6, 21) and (4, 46)
# last numbers and positions (9, 42) and (4, 46)
# Final first and last numbers (6, 4)
# -----------------
# one6qhcqnkqc9hfrsqpxmcm7eight3
#
# first numbers and positions (1, 0) and (6, 3)
# last numbers and positions (8, 24) and (3, 29)
# Final first and last numbers (1, 3)
# -----------------
# threepdtshdskxgeightjtdpfbtlnph91
#
# first numbers and positions (3, 0) and (9, 31)
# last numbers and positions (8, 15) and (1, 32)
# Final first and last numbers (3, 1)
# -----------------
# fmpjgjqpgbpx8two8jzqchdglhtfiveeightpzktj
#
# first numbers and positions (2, 13) and (8, 12)
# last numbers and positions (8, 31) and (8, 16)
# Final first and last numbers (8, 8)
# -----------------
# njqhghlvm2
#
# first numbers and positions (None, None) and (2, 9)
# last numbers and positions (None, None) and (2, 9)
# Final first and last numbers (2, 2)
# -----------------
# dj3
#
# first numbers and positions (None, None) and (3, 2)
# last numbers and positions (None, None) and (3, 2)
# Final first and last numbers (3, 3)
# -----------------
# 3j
#
# first numbers and positions (None, None) and (3, 0)
# last numbers and positions (None, None) and (3, 0)
# Final first and last numbers (3, 3)
# -----------------
# eight9cgbcppzjbl1tgjhm
#
# first numbers and positions (8, 0) and (9, 5)
# last numbers and positions (None, None) and (1, 16)
# Final first and last numbers (8, 1)
# -----------------
# fvkhcvflpknqnh9ninetwoneqn
#
# first numbers and positions (9, 15) and (9, 14)
# last numbers and positions (1, 21) and (9, 14)
# Final first and last numbers (9, 1)
# -----------------
# threemfour3eighteight
#
# first numbers and positions (3, 0) and (3, 10)
# last numbers and positions (8, 16) and (3, 10)
# Final first and last numbers (3, 8)
# -----------------
# qjmtvcbvzzgxmmpdvrfv8
#
# first numbers and positions (None, None) and (8, 20)
# last numbers and positions (None, None) and (8, 20)
# Final first and last numbers (8, 8)
# -----------------
# tlzqpfsix1fbhgdvhblvgk
#
# first numbers and positions (6, 6) and (1, 9)
# last numbers and positions (6, 6) and (1, 9)
# Final first and last numbers (6, 1)
# -----------------
# eight451qvnhv4
#
# first numbers and positions (8, 0) and (4, 5)
# last numbers and positions (None, None) and (4, 13)
# Final first and last numbers (8, 4)
# -----------------
# 7mxcvmpkdvdsjqdd
#
# first numbers and positions (None, None) and (7, 0)
# last numbers and positions (None, None) and (7, 0)
# Final first and last numbers (7, 7)
# -----------------
# 6ninetwodmbjfour52
#
# first numbers and positions (9, 1) and (6, 0)
# last numbers and positions (4, 12) and (2, 17)
# Final first and last numbers (6, 2)
# -----------------
# jdq2sheight
#
# first numbers and positions (8, 6) and (2, 3)
# last numbers and positions (8, 6) and (2, 3)
# Final first and last numbers (2, 8)
# -----------------
# seven2foursixvhlmsjld
#
# first numbers and positions (7, 0) and (2, 5)
# last numbers and positions (6, 10) and (2, 5)
# Final first and last numbers (7, 6)
# -----------------
# ndoneight361
#
# first numbers and positions (1, 2) and (3, 9)
# last numbers and positions (8, 4) and (1, 11)
# Final first and last numbers (1, 1)
# -----------------
# poneightfourfourdhlnmlnpvnsixone77
#
# first numbers and positions (1, 1) and (7, 32)
# last numbers and positions (1, 29) and (7, 33)
# Final first and last numbers (1, 7)
# -----------------
# 6gnxprrthree9
#
# first numbers and positions (3, 7) and (6, 0)
# last numbers and positions (3, 7) and (9, 12)
# Final first and last numbers (6, 9)
# -----------------
# ktbhqxmvcbczfspfddnjjcz7
#
# first numbers and positions (None, None) and (7, 23)
# last numbers and positions (None, None) and (7, 23)
# Final first and last numbers (7, 7)
# -----------------
# 4nineqsk5two5ksljzqmnrrhftqvmvhfqvxtg
#
# first numbers and positions (9, 1) and (4, 0)
# last numbers and positions (2, 9) and (5, 12)
# Final first and last numbers (4, 5)
# -----------------
# cgllkmq1fivevlcxkmj4twohpclqj
#
# first numbers and positions (5, 8) and (1, 7)
# last numbers and positions (2, 20) and (4, 19)
# Final first and last numbers (1, 2)
# -----------------
# fivebdkfgmlzckstbmone58fourc1
#
# first numbers and positions (5, 0) and (5, 21)
# last numbers and positions (4, 23) and (1, 28)
# Final first and last numbers (5, 1)
# -----------------
# 6sixninebkmlgpspthreesevenhfrhtfqnl85
#
# first numbers and positions (6, 1) and (6, 0)
# last numbers and positions (7, 21) and (5, 36)
# Final first and last numbers (6, 5)
# -----------------
# 27fivezqskxvqqp7
#
# first numbers and positions (5, 2) and (2, 0)
# last numbers and positions (5, 2) and (7, 15)
# Final first and last numbers (2, 7)
# -----------------
# 7vklrcvmq2nldrglnlkmdjgzone
#
# first numbers and positions (1, 24) and (7, 0)
# last numbers and positions (1, 24) and (2, 9)
# Final first and last numbers (7, 1)
# -----------------
# 4fivemzjhhvmm
#
# first numbers and positions (5, 1) and (4, 0)
# last numbers and positions (5, 1) and (4, 0)
# Final first and last numbers (4, 5)
# -----------------
# 76fournineeightthreesix
#
# first numbers and positions (4, 2) and (7, 0)
# last numbers and positions (6, 20) and (6, 1)
# Final first and last numbers (7, 6)
# -----------------
# threen45nctdxmgd
#
# first numbers and positions (3, 0) and (4, 6)
# last numbers and positions (None, None) and (5, 7)
# Final first and last numbers (3, 5)
# -----------------
# eightfivetwotjbsvvrfourseven4djjfftk9
#
# first numbers and positions (8, 0) and (4, 28)
# last numbers and positions (7, 23) and (9, 36)
# Final first and last numbers (8, 9)
# -----------------
# lrxjcgdxhtprfpvn9eightsix
#
# first numbers and positions (8, 17) and (9, 16)
# last numbers and positions (6, 22) and (9, 16)
# Final first and last numbers (9, 6)
# -----------------
# foursix7lbjqxb1lzsztxcrhx
#
# first numbers and positions (4, 0) and (7, 7)
# last numbers and positions (6, 4) and (1, 14)
# Final first and last numbers (4, 1)
# -----------------
# dlxftspksone9mfive
#
# first numbers and positions (1, 9) and (9, 12)
# last numbers and positions (5, 14) and (9, 12)
# Final first and last numbers (1, 5)
# -----------------
# ninefiveeightone2
#
# first numbers and positions (9, 0) and (2, 16)
# last numbers and positions (1, 13) and (2, 16)
# Final first and last numbers (9, 2)
# -----------------
# nzbvf3ninexsixsix
#
# first numbers and positions (9, 6) and (3, 5)
# last numbers and positions (6, 14) and (3, 5)
# Final first and last numbers (3, 6)
# -----------------
# 1eightjsqbvpcfsevenvdkhbxzfournine5pttjffj
#
# first numbers and positions (8, 1) and (1, 0)
# last numbers and positions (9, 30) and (5, 34)
# Final first and last numbers (1, 5)
# -----------------
# 6kxdmlhtslf2rzmbrdrvvqmtceightwojj
#
# first numbers and positions (8, 25) and (6, 0)
# last numbers and positions (2, 29) and (2, 11)
# Final first and last numbers (6, 2)
# -----------------
# 3fjxhq
#
# first numbers and positions (None, None) and (3, 0)
# last numbers and positions (None, None) and (3, 0)
# Final first and last numbers (3, 3)
# -----------------
# j9
#
# first numbers and positions (None, None) and (9, 1)
# last numbers and positions (None, None) and (9, 1)
# Final first and last numbers (9, 9)
# -----------------
# lj7onesevennine7threeeightvmgvtzcg
#
# first numbers and positions (1, 3) and (7, 2)
# last numbers and positions (8, 21) and (7, 15)
# Final first and last numbers (7, 8)
# -----------------
# pmmrbq4
#
# first numbers and positions (None, None) and (4, 6)
# last numbers and positions (None, None) and (4, 6)
# Final first and last numbers (4, 4)
# -----------------
# seven3fourq81l
#
# first numbers and positions (7, 0) and (3, 5)
# last numbers and positions (4, 6) and (1, 12)
# Final first and last numbers (7, 1)
# -----------------
# 2four4gqdpczpg
#
# first numbers and positions (4, 1) and (2, 0)
# last numbers and positions (4, 1) and (4, 5)
# Final first and last numbers (2, 4)
# -----------------
# 6sevengzdxmfpflfivefivevgnhspxchsfive
#
# first numbers and positions (7, 1) and (6, 0)
# last numbers and positions (5, 33) and (6, 0)
# Final first and last numbers (6, 5)
# -----------------
# 3c7gpgbnlfhlrthpmtsvpctjhzf5seven
#
# first numbers and positions (7, 28) and (3, 0)
# last numbers and positions (7, 28) and (5, 27)
# Final first and last numbers (3, 7)
# -----------------
# kgtczfjdeight8hpcmkz
#
# first numbers and positions (8, 8) and (8, 13)
# last numbers and positions (8, 8) and (8, 13)
# Final first and last numbers (8, 8)
# -----------------
# one5xkhnfvjh92ninevxkzvkg6
#
# first numbers and positions (1, 0) and (5, 3)
# last numbers and positions (9, 14) and (6, 25)
# Final first and last numbers (1, 6)
# -----------------
# nzp2
#
# first numbers and positions (None, None) and (2, 3)
# last numbers and positions (None, None) and (2, 3)
# Final first and last numbers (2, 2)
# -----------------
# eight226three5sevenhhxhqxns
#
# first numbers and positions (8, 0) and (2, 5)
# last numbers and positions (7, 14) and (5, 13)
# Final first and last numbers (8, 7)
# -----------------
# 9hgfj85zxvppflblvjlq
#
# first numbers and positions (None, None) and (9, 0)
# last numbers and positions (None, None) and (5, 6)
# Final first and last numbers (9, 5)
# -----------------
# sixfour8hzlrbqjtjcgrxseight
#
# first numbers and positions (6, 0) and (8, 7)
# last numbers and positions (8, 22) and (8, 7)
# Final first and last numbers (6, 8)
# -----------------
# 6tlxtwo4258kbdtx
#
# first numbers and positions (2, 4) and (6, 0)
# last numbers and positions (2, 4) and (8, 10)
# Final first and last numbers (6, 8)
# -----------------
# ninemhvrlcqvdthree5
#
# first numbers and positions (9, 0) and (5, 18)
# last numbers and positions (3, 13) and (5, 18)
# Final first and last numbers (9, 5)
# -----------------
# 8xfmjzp
#
# first numbers and positions (None, None) and (8, 0)
# last numbers and positions (None, None) and (8, 0)
# Final first and last numbers (8, 8)
# -----------------
# nineldrbpxqmhffrjrcx11
#
# first numbers and positions (9, 0) and (1, 20)
# last numbers and positions (None, None) and (1, 21)
# Final first and last numbers (9, 1)
# -----------------
# mqvjnkjr6dx8
#
# first numbers and positions (None, None) and (6, 8)
# last numbers and positions (None, None) and (8, 11)
# Final first and last numbers (6, 8)
# -----------------
# 575cfbnine14
#
# first numbers and positions (9, 6) and (5, 0)
# last numbers and positions (9, 6) and (4, 11)
# Final first and last numbers (5, 4)
# -----------------
# threeqnxnfjmttwo7
#
# first numbers and positions (3, 0) and (7, 16)
# last numbers and positions (2, 13) and (7, 16)
# Final first and last numbers (3, 7)
# -----------------
# pvmxfgvhrlqn4fivefivesevensix1znt
#
# first numbers and positions (5, 13) and (4, 12)
# last numbers and positions (6, 26) and (1, 29)
# Final first and last numbers (4, 1)
# -----------------
# sevenphcrjjhnfive63three
#
# first numbers and positions (7, 0) and (6, 17)
# last numbers and positions (3, 19) and (3, 18)
# Final first and last numbers (7, 3)
# -----------------
# sixxdjplseven8seven8qlxfvgktf
#
# first numbers and positions (6, 0) and (8, 13)
# last numbers and positions (7, 14) and (8, 19)
# Final first and last numbers (6, 8)
# -----------------
# hdgnr6sevenddzptcvprbhvnine
#
# first numbers and positions (7, 6) and (6, 5)
# last numbers and positions (9, 23) and (6, 5)
# Final first and last numbers (6, 9)
# -----------------
# onebrhnsqbnzvmckmtmprjkbfvn6
#
# first numbers and positions (1, 0) and (6, 27)
# last numbers and positions (None, None) and (6, 27)
# Final first and last numbers (1, 6)
# -----------------
# hxqdjrmr94five9qnkl5
#
# first numbers and positions (5, 10) and (9, 8)
# last numbers and positions (5, 10) and (5, 19)
# Final first and last numbers (9, 5)
# -----------------
# g3fourfive6
#
# first numbers and positions (4, 2) and (3, 1)
# last numbers and positions (5, 6) and (6, 10)
# Final first and last numbers (3, 6)
# -----------------
# 22eight6vsmtrxsix78
#
# first numbers and positions (8, 2) and (2, 0)
# last numbers and positions (6, 14) and (8, 18)
# Final first and last numbers (2, 8)
# -----------------
# jrlrfsnine9
#
# first numbers and positions (9, 6) and (9, 10)
# last numbers and positions (9, 6) and (9, 10)
# Final first and last numbers (9, 9)
# -----------------
# tqpkqdtknvfj2xgzrjpsvgphlbtthree
#
# first numbers and positions (3, 27) and (2, 12)
# last numbers and positions (3, 27) and (2, 12)
# Final first and last numbers (2, 3)
# -----------------
# qvczktnrfvmgpznspqtsevensevenslmjdqfdld5rrcfour
#
# first numbers and positions (7, 19) and (5, 39)
# last numbers and positions (4, 43) and (5, 39)
# Final first and last numbers (7, 4)
# -----------------
# rmgeight36sxvxzgnine7bs
#
# first numbers and positions (8, 3) and (3, 8)
# last numbers and positions (9, 16) and (7, 20)
# Final first and last numbers (8, 7)
# -----------------
# sevenlt2fnqjtkvrj
#
# first numbers and positions (7, 0) and (2, 7)
# last numbers and positions (None, None) and (2, 7)
# Final first and last numbers (7, 2)
# -----------------
# seven9lhfzhmhdonelxvxfqdlxlscjbqgvnlbm7
#
# first numbers and positions (7, 0) and (9, 5)
# last numbers and positions (1, 14) and (7, 38)
# Final first and last numbers (7, 7)
# -----------------
# 3183six4seven4two
#
# first numbers and positions (6, 4) and (3, 0)
# last numbers and positions (2, 14) and (4, 13)
# Final first and last numbers (3, 2)
# -----------------
# bpl12mcdpzrzbph9fourninercpqzrn
#
# first numbers and positions (4, 16) and (1, 3)
# last numbers and positions (9, 20) and (9, 15)
# Final first and last numbers (1, 9)
# -----------------
# eightzltzdmcd4615nmone
#
# first numbers and positions (8, 0) and (4, 13)
# last numbers and positions (1, 19) and (5, 16)
# Final first and last numbers (8, 1)
# -----------------
# 5bgzh8hrrtjhnine62
#
# first numbers and positions (9, 12) and (5, 0)
# last numbers and positions (9, 12) and (2, 17)
# Final first and last numbers (5, 2)
# -----------------
# ndnzpnptz6twokdvg563fiveqkszkccqc
#
# first numbers and positions (2, 10) and (6, 9)
# last numbers and positions (5, 20) and (3, 19)
# Final first and last numbers (6, 5)
# -----------------
# 6npdfqtwo
#
# first numbers and positions (2, 6) and (6, 0)
# last numbers and positions (2, 6) and (6, 0)
# Final first and last numbers (6, 2)
# -----------------
# onetwomcxkncm3mjsrknhktgdfbqjmone
#
# first numbers and positions (1, 0) and (3, 13)
# last numbers and positions (1, 30) and (3, 13)
# Final first and last numbers (1, 1)
# -----------------
# sixtpmdfmrjone6six
#
# first numbers and positions (6, 0) and (6, 14)
# last numbers and positions (6, 15) and (6, 14)
# Final first and last numbers (6, 6)
# -----------------
# 7fourthreekqvbhfourfivenine
#
# first numbers and positions (4, 1) and (7, 0)
# last numbers and positions (9, 23) and (7, 0)
# Final first and last numbers (7, 9)
# -----------------
# 98337
#
# first numbers and positions (None, None) and (9, 0)
# last numbers and positions (None, None) and (7, 4)
# Final first and last numbers (9, 7)
# -----------------
# pvkrzdzbdj9
#
# first numbers and positions (None, None) and (9, 10)
# last numbers and positions (None, None) and (9, 10)
# Final first and last numbers (9, 9)
# -----------------
# 8krztxtqkqksixr264
#
# first numbers and positions (6, 11) and (8, 0)
# last numbers and positions (6, 11) and (4, 17)
# Final first and last numbers (8, 4)
# -----------------
# 5sppmxxkdonezfvbdcsix
#
# first numbers and positions (1, 9) and (5, 0)
# last numbers and positions (6, 18) and (5, 0)
# Final first and last numbers (5, 6)
# -----------------
# dhvmctjcjfivec7pjmtnlqs
#
# first numbers and positions (5, 9) and (7, 14)
# last numbers and positions (5, 9) and (7, 14)
# Final first and last numbers (5, 7)
# -----------------
# dgzl9sixggxstwoneprr
#
# first numbers and positions (6, 5) and (9, 4)
# last numbers and positions (1, 14) and (9, 4)
# Final first and last numbers (9, 1)
# -----------------
# gnbmxn1cjnq3three6rpsrqmtwo
#
# first numbers and positions (3, 12) and (1, 6)
# last numbers and positions (2, 24) and (6, 17)
# Final first and last numbers (1, 2)
# -----------------
# 176seven17six
#
# first numbers and positions (7, 3) and (1, 0)
# last numbers and positions (6, 10) and (7, 9)
# Final first and last numbers (1, 6)
# -----------------
# sbvfive3six
#
# first numbers and positions (5, 3) and (3, 7)
# last numbers and positions (6, 8) and (3, 7)
# Final first and last numbers (5, 6)
# -----------------
# 8seventhree64pcffive
#
# first numbers and positions (7, 1) and (8, 0)
# last numbers and positions (5, 16) and (4, 12)
# Final first and last numbers (8, 5)
# -----------------
# fourgvhbrsfjzsevenfivenineninesixznq2
#
# first numbers and positions (4, 0) and (2, 36)
# last numbers and positions (6, 30) and (2, 36)
# Final first and last numbers (4, 2)
# -----------------
# nine426six8zk
#
# first numbers and positions (9, 0) and (4, 4)
# last numbers and positions (6, 7) and (8, 10)
# Final first and last numbers (9, 8)
# -----------------
# 4sevenfpnmsqlhllrxrhjonesmgfhzmhvstwo3
#
# first numbers and positions (7, 1) and (4, 0)
# last numbers and positions (2, 34) and (3, 37)
# Final first and last numbers (4, 3)
# -----------------
# fivesixtwosevenlfbpczfv3six8
#
# first numbers and positions (5, 0) and (3, 23)
# last numbers and positions (6, 24) and (8, 27)
# Final first and last numbers (5, 8)
# -----------------
# 8fourltcpdnhg178fourglz
#
# first numbers and positions (4, 1) and (8, 0)
# last numbers and positions (4, 16) and (8, 15)
# Final first and last numbers (8, 4)
# -----------------
# rdfqcdrxdc6twotwo8fourthreeftrlzseven
#
# first numbers and positions (2, 11) and (6, 10)
# last numbers and positions (7, 32) and (8, 17)
# Final first and last numbers (6, 7)
# -----------------
# 97threefive7
#
# first numbers and positions (3, 2) and (9, 0)
# last numbers and positions (5, 7) and (7, 11)
# Final first and last numbers (9, 7)
# -----------------
# sevenoneoneszdxd77two
#
# first numbers and positions (7, 0) and (7, 16)
# last numbers and positions (2, 18) and (7, 17)
# Final first and last numbers (7, 2)
# -----------------
# g91q392four
#
# first numbers and positions (4, 7) and (9, 1)
# last numbers and positions (4, 7) and (2, 6)
# Final first and last numbers (9, 4)
# -----------------
# 2twodb
#
# first numbers and positions (2, 1) and (2, 0)
# last numbers and positions (2, 1) and (2, 0)
# Final first and last numbers (2, 2)
# -----------------
# jbtfkfourggc5zkc3nineninekv
#
# first numbers and positions (4, 5) and (5, 12)
# last numbers and positions (9, 21) and (3, 16)
# Final first and last numbers (4, 9)
# -----------------
# 379eight
#
# first numbers and positions (8, 3) and (3, 0)
# last numbers and positions (8, 3) and (9, 2)
# Final first and last numbers (3, 8)
# -----------------
# hhxcbflcv6fiveszpch46
#
# first numbers and positions (5, 10) and (6, 9)
# last numbers and positions (5, 10) and (6, 20)
# Final first and last numbers (6, 6)
# -----------------
# threexfsfv3dpfourfiveone
#
# first numbers and positions (3, 0) and (3, 10)
# last numbers and positions (1, 21) and (3, 10)
# Final first and last numbers (3, 1)
# -----------------
# fivevd145one629
#
# first numbers and positions (5, 0) and (1, 6)
# last numbers and positions (1, 9) and (9, 14)
# Final first and last numbers (5, 9)
# -----------------
# 31vdzxxkxsmznrqjzpqj5onescbck
#
# first numbers and positions (1, 21) and (3, 0)
# last numbers and positions (1, 21) and (5, 20)
# Final first and last numbers (3, 1)
# -----------------
# 9onejbnvrbmtgm
#
# first numbers and positions (1, 1) and (9, 0)
# last numbers and positions (1, 1) and (9, 0)
# Final first and last numbers (9, 1)
# -----------------
# thrjvpckm4vglthree
#
# first numbers and positions (3, 13) and (4, 9)
# last numbers and positions (3, 13) and (4, 9)
# Final first and last numbers (4, 3)
# -----------------
# zvhmxzsixfjddvjq1four8lktthree
#
# first numbers and positions (6, 6) and (1, 16)
# last numbers and positions (3, 25) and (8, 21)
# Final first and last numbers (6, 3)
# -----------------
# 74seven84rslpcjtpfourcvvqlstmqn
#
# first numbers and positions (7, 2) and (7, 0)
# last numbers and positions (4, 17) and (4, 8)
# Final first and last numbers (7, 4)
# -----------------
# dfxdqr3eighthfhcldhgmjcpbxbzp
#
# first numbers and positions (8, 7) and (3, 6)
# last numbers and positions (8, 7) and (3, 6)
# Final first and last numbers (3, 8)
# -----------------
# sevenbgs1seven9bjntphktdktzhrzpfcfs
#
# first numbers and positions (7, 0) and (1, 8)
# last numbers and positions (7, 9) and (9, 14)
# Final first and last numbers (7, 9)
# -----------------
# 7kqkdzncd4sevensevenfourv8two
#
# first numbers and positions (7, 10) and (7, 0)
# last numbers and positions (2, 26) and (8, 25)
# Final first and last numbers (7, 2)
# -----------------
# mjeightwolsk2sgnhgxstfourhbhthreeonenine3
#
# first numbers and positions (8, 2) and (2, 12)
# last numbers and positions (9, 36) and (3, 40)
# Final first and last numbers (8, 3)
# -----------------
# 4nts
#
# first numbers and positions (None, None) and (4, 0)
# last numbers and positions (None, None) and (4, 0)
# Final first and last numbers (4, 4)
# -----------------
# nslvxzffoureightfour5eightczsptpg8
#
# first numbers and positions (4, 7) and (5, 20)
# last numbers and positions (8, 21) and (8, 33)
# Final first and last numbers (4, 8)
# -----------------
# bcckncblzdsixxrdprtsmbjdzxzlnzfbgmkfd2
#
# first numbers and positions (6, 10) and (2, 37)
# last numbers and positions (6, 10) and (2, 37)
# Final first and last numbers (6, 2)
# -----------------
# 8fourninesix4fourseven
#
# first numbers and positions (4, 1) and (8, 0)
# last numbers and positions (7, 17) and (4, 12)
# Final first and last numbers (8, 7)
# -----------------
# twospxvtbcjfour3seven
#
# first numbers and positions (2, 0) and (3, 15)
# last numbers and positions (7, 16) and (3, 15)
# Final first and last numbers (2, 7)
# -----------------
# four2cqkxkbplbpb
#
# first numbers and positions (4, 0) and (2, 4)
# last numbers and positions (None, None) and (2, 4)
# Final first and last numbers (4, 2)
# -----------------
# 54fourtwo2xd
#
# first numbers and positions (4, 2) and (5, 0)
# last numbers and positions (2, 6) and (2, 9)
# Final first and last numbers (5, 2)
# -----------------
# tljfive7bsxmonesixl
#
# first numbers and positions (5, 3) and (7, 7)
# last numbers and positions (6, 15) and (7, 7)
# Final first and last numbers (5, 6)
# -----------------
# 8mxd8czpdrgxbtwoeightrqpghngcvt
#
# first numbers and positions (2, 13) and (8, 0)
# last numbers and positions (8, 16) and (8, 4)
# Final first and last numbers (8, 8)
# -----------------
# 3sxrzljnzlr9threetknfcc5seven4
#
# first numbers and positions (3, 12) and (3, 0)
# last numbers and positions (7, 24) and (4, 29)
# Final first and last numbers (3, 4)
# -----------------
# eighteightfourtwo8fournine7
#
# first numbers and positions (8, 0) and (8, 17)
# last numbers and positions (9, 22) and (7, 26)
# Final first and last numbers (8, 7)
# -----------------
# jjzxf153mdzhh
#
# first numbers and positions (None, None) and (1, 5)
# last numbers and positions (None, None) and (3, 7)
# Final first and last numbers (1, 3)
# -----------------
# 3three95one8vsmzkrlvhq
#
# first numbers and positions (3, 1) and (3, 0)
# last numbers and positions (1, 8) and (8, 11)
# Final first and last numbers (3, 8)
# -----------------
# ninefour4pzqzntwo2nine
#
# first numbers and positions (9, 0) and (4, 8)
# last numbers and positions (9, 18) and (2, 17)
# Final first and last numbers (9, 9)
# -----------------
# onefournine8gvp
#
# first numbers and positions (1, 0) and (8, 11)
# last numbers and positions (9, 7) and (8, 11)
# Final first and last numbers (1, 8)
# -----------------
# 45vmbrpblzjxthhonesix8
#
# first numbers and positions (1, 15) and (4, 0)
# last numbers and positions (6, 18) and (8, 21)
# Final first and last numbers (4, 8)
# -----------------
# lmmrxm5
#
# first numbers and positions (None, None) and (5, 6)
# last numbers and positions (None, None) and (5, 6)
# Final first and last numbers (5, 5)
# -----------------
# 13mhm6zxmkhbcsixhz8
#
# first numbers and positions (6, 13) and (1, 0)
# last numbers and positions (6, 13) and (8, 18)
# Final first and last numbers (1, 8)
# -----------------
# mhsjcprhdh7ninemgrxnqzt7pdtxxvsix
#
# first numbers and positions (9, 11) and (7, 10)
# last numbers and positions (6, 30) and (7, 23)
# Final first and last numbers (7, 6)
# -----------------
# twothreesixqcjtzcxmd3ninezqrvnzlxt
#
# first numbers and positions (2, 0) and (3, 20)
# last numbers and positions (9, 21) and (3, 20)
# Final first and last numbers (2, 9)
# -----------------
# hreightwo51tb27fivesevenseven
#
# first numbers and positions (8, 2) and (5, 9)
# last numbers and positions (7, 24) and (7, 14)
# Final first and last numbers (8, 7)
# -----------------
# fivebktq86nine5kd
#
# first numbers and positions (5, 0) and (8, 8)
# last numbers and positions (9, 10) and (5, 14)
# Final first and last numbers (5, 5)
# -----------------
# one6nglzxzkzrmfl12nine6
#
# first numbers and positions (1, 0) and (6, 3)
# last numbers and positions (9, 18) and (6, 22)
# Final first and last numbers (1, 6)
# -----------------
# 2th9mms4six3
#
# first numbers and positions (6, 8) and (2, 0)
# last numbers and positions (6, 8) and (3, 11)
# Final first and last numbers (2, 3)
# -----------------
# msix5bqbtwosix
#
# first numbers and positions (6, 1) and (5, 4)
# last numbers and positions (6, 11) and (5, 4)
# Final first and last numbers (6, 6)
# -----------------
# four1hfrmxsix3five
#
# first numbers and positions (4, 0) and (1, 4)
# last numbers and positions (5, 14) and (3, 13)
# Final first and last numbers (4, 5)
# -----------------
# nrtjrkkfour6fivefour7fivertjnxbbzg
#
# first numbers and positions (4, 7) and (6, 11)
# last numbers and positions (5, 21) and (7, 20)
# Final first and last numbers (4, 5)
# -----------------
# jmjqmxrtjr23phttwo
#
# first numbers and positions (2, 15) and (2, 10)
# last numbers and positions (2, 15) and (3, 11)
# Final first and last numbers (2, 2)
# -----------------
# 79
#
# first numbers and positions (None, None) and (7, 0)
# last numbers and positions (None, None) and (9, 1)
# Final first and last numbers (7, 9)
# -----------------
# 6twones
#
# first numbers and positions (2, 1) and (6, 0)
# last numbers and positions (1, 3) and (6, 0)
# Final first and last numbers (6, 1)
# -----------------
# sn6fivesixfourhhjhrfthree
#
# first numbers and positions (5, 3) and (6, 2)
# last numbers and positions (3, 20) and (6, 2)
# Final first and last numbers (6, 3)
# -----------------
# xdfxgzccsvonefivenmqleightfivel9nine
#
# first numbers and positions (1, 10) and (9, 31)
# last numbers and positions (9, 32) and (9, 31)
# Final first and last numbers (1, 9)
# -----------------
# 78sevensix21
#
# first numbers and positions (7, 2) and (7, 0)
# last numbers and positions (6, 7) and (1, 11)
# Final first and last numbers (7, 1)
# -----------------
# rkmncslfr6hdhtlchnznineoneeight4
#
# first numbers and positions (9, 19) and (6, 9)
# last numbers and positions (8, 26) and (4, 31)
# Final first and last numbers (6, 4)
# -----------------
# seven1496
#
# first numbers and positions (7, 0) and (1, 5)
# last numbers and positions (None, None) and (6, 8)
# Final first and last numbers (7, 6)
# -----------------
# 8fivekhfrfjtwo3eight9six4
#
# first numbers and positions (5, 1) and (8, 0)
# last numbers and positions (6, 21) and (4, 24)
# Final first and last numbers (8, 4)
# -----------------
# jnrtwoneslxrgkeight67fivetwolbhvfftqjhl
#
# first numbers and positions (2, 3) and (6, 19)
# last numbers and positions (2, 25) and (7, 20)
# Final first and last numbers (2, 2)
# -----------------
# eight6eight4two
#
# first numbers and positions (8, 0) and (6, 5)
# last numbers and positions (2, 12) and (4, 11)
# Final first and last numbers (8, 2)
# -----------------
# dhcxc1
#
# first numbers and positions (None, None) and (1, 5)
# last numbers and positions (None, None) and (1, 5)
# Final first and last numbers (1, 1)
# -----------------
# fivenpblbgfive6moneighttzj
#
# first numbers and positions (5, 0) and (6, 14)
# last numbers and positions (8, 18) and (6, 14)
# Final first and last numbers (5, 8)
# -----------------
# onef5nppkqcl6mnzhvsixjvcqpbtb
#
# ...
# last numbers and positions (None, None) and (9, 2)
# Final first and last numbers (6, 9)
# -----------------
# 7vc9threenine3
#
# first numbers and positions (3, 4) and (7, 0)
# last numbers and positions (9, 9) and (3, 13)
# Final first and last numbers (7, 3)
# -----------------
# one35x
#
# first numbers and positions (1, 0) and (3, 3)
# last numbers and positions (None, None) and (5, 4)
# Final first and last numbers (1, 5)
# -----------------
# 4eightthree9
#
# first numbers and positions (8, 1) and (4, 0)
# last numbers and positions (3, 6) and (9, 11)
# Final first and last numbers (4, 9)
# -----------------
# 1hclxskfgjfhvjtgqsztp
#
# first numbers and positions (None, None) and (1, 0)
# last numbers and positions (None, None) and (1, 0)
# Final first and last numbers (1, 1)
# -----------------
# eight38d84fm
#
# first numbers and positions (8, 0) and (3, 5)
# last numbers and positions (None, None) and (4, 9)
# Final first and last numbers (8, 4)
# -----------------
# fiveone6five1five
#
# first numbers and positions (5, 0) and (6, 7)
# last numbers and positions (5, 13) and (1, 12)
# Final first and last numbers (5, 5)
# -----------------
# qjpptvfsrs614fourssdrxtpqfz7
#
# first numbers and positions (4, 13) and (6, 10)
# last numbers and positions (4, 13) and (7, 27)
# Final first and last numbers (6, 7)
# -----------------
# 9qnrkp
#
# first numbers and positions (None, None) and (9, 0)
# last numbers and positions (None, None) and (9, 0)
# Final first and last numbers (9, 9)
# -----------------
# six4one1zxhllkcd
#
# first numbers and positions (6, 0) and (4, 3)
# last numbers and positions (1, 4) and (1, 7)
# Final first and last numbers (6, 1)
# -----------------
# six1fourtwormz7vxfbhmg
#
# first numbers and positions (6, 0) and (1, 3)
# last numbers and positions (2, 8) and (7, 14)
# Final first and last numbers (6, 7)
# -----------------
# one3jxcjzz9
#
# first numbers and positions (1, 0) and (3, 3)
# last numbers and positions (None, None) and (9, 10)
# Final first and last numbers (1, 9)
# -----------------
# vzmtgdhpjneight83fivepcd
#
# first numbers and positions (8, 10) and (8, 15)
# last numbers and positions (5, 17) and (3, 16)
# Final first and last numbers (8, 5)
# -----------------
# onexqhvqpvmncljmssix4twoseven
#
# first numbers and positions (1, 0) and (4, 20)
# last numbers and positions (7, 24) and (4, 20)
# Final first and last numbers (1, 7)
# -----------------
# threeninenine2hg
#
# first numbers and positions (3, 0) and (2, 13)
# last numbers and positions (9, 9) and (2, 13)
# Final first and last numbers (3, 2)
# -----------------
# bvjvgtdhjstsevengtbnqf4seven8two
#
# first numbers and positions (7, 11) and (4, 22)
# last numbers and positions (2, 29) and (8, 28)
# Final first and last numbers (7, 2)
# -----------------
# twooneone5lrjpptxzd
#
# first numbers and positions (2, 0) and (5, 9)
# last numbers and positions (1, 6) and (5, 9)
# Final first and last numbers (2, 5)
# -----------------
# hzlb1
#
# first numbers and positions (None, None) and (1, 4)
# last numbers and positions (None, None) and (1, 4)
# Final first and last numbers (1, 1)
# -----------------
# nhrbfltwosix22rdjthctone
#
# first numbers and positions (2, 6) and (2, 12)
# last numbers and positions (1, 21) and (2, 13)
# Final first and last numbers (2, 1)
# -----------------
# seven7eightthreepgj
#
# first numbers and positions (7, 0) and (7, 5)
# last numbers and positions (3, 11) and (7, 5)
# Final first and last numbers (7, 3)
# -----------------
# fourfive45
#
# first numbers and positions (4, 0) and (4, 8)
# last numbers and positions (5, 4) and (5, 9)
# Final first and last numbers (4, 5)
# -----------------
# nztwohnx3nine
#
# first numbers and positions (2, 2) and (3, 8)
# last numbers and positions (9, 9) and (3, 8)
# Final first and last numbers (2, 9)
# -----------------
# fourhfxgmkcgbppdjkqpx2ninezdkbncsevengbdxb
#
# first numbers and positions (4, 0) and (2, 21)
# last numbers and positions (7, 32) and (2, 21)
# Final first and last numbers (4, 7)
# -----------------
# sbzdcpxnine3nine
#
# first numbers and positions (9, 7) and (3, 11)
# last numbers and positions (9, 12) and (3, 11)
# Final first and last numbers (9, 9)
# -----------------
# 8grdrone78
#
# first numbers and positions (1, 5) and (8, 0)
# last numbers and positions (1, 5) and (8, 9)
# Final first and last numbers (8, 8)
# -----------------
# 1eightjldlllrxl2
#
# first numbers and positions (8, 1) and (1, 0)
# last numbers and positions (8, 1) and (2, 15)
# Final first and last numbers (1, 2)
# -----------------
# 588onethreesixlpdkxfc
#
# first numbers and positions (1, 3) and (5, 0)
# last numbers and positions (6, 11) and (8, 2)
# Final first and last numbers (5, 6)
# -----------------
# vvvjrnzbfxgzxqlxx6vcqkkftxkdttnhpzrvtwo
#
# first numbers and positions (2, 36) and (6, 17)
# last numbers and positions (2, 36) and (6, 17)
# Final first and last numbers (6, 2)
# -----------------
# 3llpjrhrone5ninemdqjnpllprkphk
#
# first numbers and positions (1, 8) and (3, 0)
# last numbers and positions (9, 12) and (5, 11)
# Final first and last numbers (3, 9)
# -----------------
# 44pmxlrhsdsvsfxtg6
#
# first numbers and positions (None, None) and (4, 0)
# last numbers and positions (None, None) and (6, 17)
# Final first and last numbers (4, 6)
# -----------------
# nine841jvpl
#
# first numbers and positions (9, 0) and (8, 4)
# last numbers and positions (None, None) and (1, 6)
# Final first and last numbers (9, 1)
# -----------------
# eightbpsqrkzhqbhjlrxmzsixvvmgtrseventwo7oneightjbx
#
# first numbers and positions (8, 0) and (7, 39)
# last numbers and positions (8, 42) and (7, 39)
# Final first and last numbers (8, 8)
# -----------------
# znhjtgjk1three8
#
# first numbers and positions (3, 9) and (1, 8)
# last numbers and positions (3, 9) and (8, 14)
# Final first and last numbers (1, 8)
# -----------------
# 5xcsvvvzrqcxkqj346oneprztsfpdld6
#
# first numbers and positions (1, 18) and (5, 0)
# last numbers and positions (1, 18) and (6, 31)
# Final first and last numbers (5, 6)
# -----------------
# 67six1four1kqj
#
# first numbers and positions (6, 2) and (6, 0)
# last numbers and positions (4, 6) and (1, 10)
# Final first and last numbers (6, 1)
# -----------------
# qvqlmqtzcj5
#
# first numbers and positions (None, None) and (5, 10)
# last numbers and positions (None, None) and (5, 10)
# Final first and last numbers (5, 5)
# -----------------
# ninejrrhddqfivenine7psghccdhvfive
#
# first numbers and positions (9, 0) and (7, 19)
# last numbers and positions (5, 29) and (7, 19)
# Final first and last numbers (9, 5)
# -----------------
# pznvtxdklpvqbsevenfiveninehzjfvrdxz8
#
# first numbers and positions (7, 13) and (8, 35)
# last numbers and positions (9, 22) and (8, 35)
# Final first and last numbers (7, 8)
# -----------------
# eight46xpfdcqbmprchftkpfive
#
# first numbers and positions (8, 0) and (4, 5)
# last numbers and positions (5, 23) and (6, 6)
# Final first and last numbers (8, 5)
# -----------------
# bkdvhbhlmn1
#
# first numbers and positions (None, None) and (1, 10)
# last numbers and positions (None, None) and (1, 10)
# Final first and last numbers (1, 1)
# -----------------
# 99sixv
#
# first numbers and positions (6, 2) and (9, 0)
# last numbers and positions (6, 2) and (9, 1)
# Final first and last numbers (9, 6)
# -----------------
# gdoneight26pzghbjfeightttfbvhltwo8
#
# first numbers and positions (1, 2) and (2, 9)
# last numbers and positions (2, 30) and (8, 33)
# Final first and last numbers (1, 8)
# -----------------
# three5nhd
#
# first numbers and positions (3, 0) and (5, 5)
# last numbers and positions (None, None) and (5, 5)
# Final first and last numbers (3, 5)
# -----------------
# three5nine
#
# first numbers and positions (3, 0) and (5, 5)
# last numbers and positions (9, 6) and (5, 5)
# Final first and last numbers (3, 9)
# -----------------
# four9csdvvfdbkseven26peight
#
# first numbers and positions (4, 0) and (9, 4)
# last numbers and positions (8, 22) and (6, 20)
# Final first and last numbers (4, 8)
# -----------------
# sevennszdbkkfdndjtzzpjmtqbxlkv43vxlnnrn
#
# first numbers and positions (7, 0) and (4, 30)
# last numbers and positions (None, None) and (3, 31)
# Final first and last numbers (7, 3)
# -----------------
# 4fourpxzkmfksix39
#
# first numbers and positions (4, 1) and (4, 0)
# last numbers and positions (6, 12) and (9, 16)
# Final first and last numbers (4, 9)
# -----------------
# 9hz8crczlbbhkrsjblzd1q9jsbf
#
# first numbers and positions (None, None) and (9, 0)
# last numbers and positions (None, None) and (9, 22)
# Final first and last numbers (9, 9)
# -----------------
# 443twofour88one
#
# first numbers and positions (2, 3) and (4, 0)
# last numbers and positions (1, 12) and (8, 11)
# Final first and last numbers (4, 1)
# -----------------
# 2tpmlxltgsix
#
# first numbers and positions (6, 9) and (2, 0)
# last numbers and positions (6, 9) and (2, 0)
# Final first and last numbers (2, 6)
# -----------------
# 83835six
#
# first numbers and positions (6, 5) and (8, 0)
# last numbers and positions (6, 5) and (5, 4)
# Final first and last numbers (8, 6)
# -----------------
# 8twojvsgjtqvxgsevennjdvdbqccmgcldp
#
# first numbers and positions (2, 1) and (8, 0)
# last numbers and positions (7, 14) and (8, 0)
# Final first and last numbers (8, 7)
# -----------------
# fivebpknnpxnjmpxntbhkjsp4fivefour
#
# first numbers and positions (5, 0) and (4, 24)
# last numbers and positions (4, 29) and (4, 24)
# Final first and last numbers (5, 4)
# -----------------
# hvxnseven6two64five2six
#
# first numbers and positions (7, 4) and (6, 9)
# last numbers and positions (6, 20) and (2, 19)
# Final first and last numbers (7, 6)
# -----------------
# 5twoonefive
#
# first numbers and positions (2, 1) and (5, 0)
# last numbers and positions (5, 7) and (5, 0)
# Final first and last numbers (5, 5)
# -----------------
# jzkd6hvcmfqsjztsixfivexlfrvn
#
# first numbers and positions (6, 15) and (6, 4)
# last numbers and positions (5, 18) and (6, 4)
# Final first and last numbers (6, 5)
# -----------------
# xfbcskone12jvvbflfn
#
# first numbers and positions (1, 6) and (1, 9)
# last numbers and positions (1, 6) and (2, 10)
# Final first and last numbers (1, 2)
# -----------------
# ninellrbqhshsxeight7two
#
# first numbers and positions (9, 0) and (7, 19)
# last numbers and positions (2, 20) and (7, 19)
# Final first and last numbers (9, 2)
# -----------------
# 4nine79jdkfkgvcr1
#
# first numbers and positions (9, 1) and (4, 0)
# last numbers and positions (9, 1) and (1, 16)
# Final first and last numbers (4, 1)
# -----------------
# eight8twoltnpxckbqxnfbxtthree49
#
# first numbers and positions (8, 0) and (8, 5)
# last numbers and positions (3, 24) and (9, 30)
# Final first and last numbers (8, 9)
# -----------------
# ctkfveight8
#
# first numbers and positions (8, 5) and (8, 10)
# last numbers and positions (8, 5) and (8, 10)
# Final first and last numbers (8, 8)
# -----------------
# nine671seventwotwonejkf
#
# first numbers and positions (9, 0) and (6, 4)
# last numbers and positions (1, 17) and (1, 6)
# Final first and last numbers (9, 1)
# -----------------
# 5threesix
#
# first numbers and positions (3, 1) and (5, 0)
# last numbers and positions (6, 6) and (5, 0)
# Final first and last numbers (5, 6)
# -----------------
# 4sixsixzfmtzlspfcseven
#
# first numbers and positions (6, 1) and (4, 0)
# last numbers and positions (7, 17) and (4, 0)
# Final first and last numbers (4, 7)
# -----------------
# 4pqnrmqlscq1fkzxngndmgseven2
#
# first numbers and positions (7, 22) and (4, 0)
# last numbers and positions (7, 22) and (2, 27)
# Final first and last numbers (4, 2)
# -----------------
# 27four7znrkvxhvt6
#
# first numbers and positions (4, 2) and (2, 0)
# last numbers and positions (4, 2) and (6, 16)
# Final first and last numbers (2, 6)
# -----------------
# lqkljjh79six7seven
#
# first numbers and positions (6, 9) and (7, 7)
# last numbers and positions (7, 13) and (7, 12)
# Final first and last numbers (7, 7)
# -----------------
# 2tlb84sixfour
#
# first numbers and positions (6, 6) and (2, 0)
# last numbers and positions (4, 9) and (4, 5)
# Final first and last numbers (2, 4)
# -----------------
# onesevenseven5htsdxvfctkdgvqtwoeight3
#
# first numbers and positions (1, 0) and (5, 13)
# last numbers and positions (8, 31) and (3, 36)
# Final first and last numbers (1, 3)
# -----------------
# 66836qblqgdhnine
#
# first numbers and positions (9, 12) and (6, 0)
# last numbers and positions (9, 12) and (6, 4)
# Final first and last numbers (6, 9)
# -----------------
# 75ntphbdbpgktwo
#
# first numbers and positions (2, 12) and (7, 0)
# last numbers and positions (2, 12) and (5, 1)
# Final first and last numbers (7, 2)
# -----------------
# jheightwovtone8fourtcsbhhntkq3nine1nine
#
# first numbers and positions (8, 2) and (8, 14)
# last numbers and positions (9, 35) and (1, 34)
# Final first and last numbers (8, 9)
# -----------------
# 5gcnnbjcgqn7
#
# first numbers and positions (None, None) and (5, 0)
# last numbers and positions (None, None) and (7, 11)
# Final first and last numbers (5, 7)
# -----------------
# 1nnxkfdmxhsqqttsfsgtwo5three
#
# first numbers and positions (2, 19) and (1, 0)
# last numbers and positions (3, 23) and (5, 22)
# Final first and last numbers (1, 3)
# -----------------
# 7sixtwoeight
#
# first numbers and positions (6, 1) and (7, 0)
# last numbers and positions (8, 7) and (7, 0)
# Final first and last numbers (7, 8)
# -----------------
# 9lsjcmcvqlconezxvrrptxlxleightlvghvxjgfive
#
# first numbers and positions (1, 11) and (9, 0)
# last numbers and positions (5, 38) and (9, 0)
# Final first and last numbers (9, 5)
# -----------------
# one6xxf1bjjnkfeightwozv
#
# first numbers and positions (1, 0) and (6, 3)
# last numbers and positions (2, 18) and (1, 7)
# Final first and last numbers (1, 2)
# -----------------
# 4rqxnflktwo
#
# first numbers and positions (2, 8) and (4, 0)
# last numbers and positions (2, 8) and (4, 0)
# Final first and last numbers (4, 2)
# -----------------
# 5three1
#
# first numbers and positions (3, 1) and (5, 0)
# last numbers and positions (3, 1) and (1, 6)
# Final first and last numbers (5, 1)
# -----------------
# vxqmbgjnr6one
#
# first numbers and positions (1, 10) and (6, 9)
# last numbers and positions (1, 10) and (6, 9)
# Final first and last numbers (6, 1)
# -----------------
# eightfour538
#
# first numbers and positions (8, 0) and (5, 9)
# last numbers and positions (4, 5) and (8, 11)
# Final first and last numbers (8, 8)
# -----------------
# gvjt1onetsevenonesixfive8
#
# first numbers and positions (1, 5) and (1, 4)
# last numbers and positions (5, 20) and (8, 24)
# Final first and last numbers (1, 8)
# -----------------
# fourgtwopbjbcvgtwo3one
#
# first numbers and positions (4, 0) and (3, 18)
# last numbers and positions (1, 19) and (3, 18)
# Final first and last numbers (4, 1)
# -----------------
# 68four4htvj8bk
#
# first numbers and positions (4, 2) and (6, 0)
# last numbers and positions (4, 2) and (8, 11)
# Final first and last numbers (6, 8)
# -----------------
# nmftgklbpj9onevbzzeightncszqgpl
#
# first numbers and positions (1, 11) and (9, 10)
# last numbers and positions (8, 18) and (9, 10)
# Final first and last numbers (9, 8)
# -----------------
# 154fnthzxccjxsztjzpvzcn4
#
# first numbers and positions (None, None) and (1, 0)
# last numbers and positions (None, None) and (4, 23)
# Final first and last numbers (1, 4)
# -----------------
# three6fivefoursixgtzfzbkhmnplfm
#
# first numbers and positions (3, 0) and (6, 5)
# last numbers and positions (6, 14) and (6, 5)
# Final first and last numbers (3, 6)
# -----------------
# 63eightsixgdsdqqxzzsbnkt782
#
# first numbers and positions (8, 2) and (6, 0)
# last numbers and positions (6, 7) and (2, 26)
# Final first and last numbers (6, 2)
# -----------------
# twovbntmfffivengfbkhzgm4
#
# first numbers and positions (2, 0) and (4, 23)
# last numbers and positions (5, 10) and (4, 23)
# Final first and last numbers (2, 4)
# -----------------
# 23sd6nnspq
#
# first numbers and positions (None, None) and (2, 0)
# last numbers and positions (None, None) and (6, 4)
# Final first and last numbers (2, 6)
# -----------------
# nineeighttworhtvxdtxp8twoneh
#
# first numbers and positions (9, 0) and (8, 21)
# last numbers and positions (1, 24) and (8, 21)
# Final first and last numbers (9, 1)
# -----------------
# four3threeonehbfhttgn39sqpctngqmzkhttn
#
# first numbers and positions (4, 0) and (3, 4)
# last numbers and positions (1, 10) and (9, 22)
# Final first and last numbers (4, 9)
# -----------------
# rphtbkncs4nznsix
#
# first numbers and positions (6, 13) and (4, 9)
# last numbers and positions (6, 13) and (4, 9)
# Final first and last numbers (4, 6)
# -----------------
# 6three2sixsix9eightfour
# first numbers and positions (3, 1) and (6, 0)
# last numbers and positions (4, 19) and (9, 13)
# Final first and last numbers (6, 4)
# 54875

# %%
print(tot)
# Out:
# 54875
